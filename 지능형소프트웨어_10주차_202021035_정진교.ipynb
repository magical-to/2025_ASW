# %% [markdown]
# <a href="https://colab.research.google.com/github/magical-to/2025_ASW/blob/main/%EC%A7%80%EB%8A%A5%ED%98%95%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4_10%EC%A3%BC%EC%B0%A8_202021035_%EC%A0%95%EC%A7%84%EA%B5%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
# ...

# %%
import openai

openai.api_key = OPENAI_API_KEY
model = "gpt-3.5-turbo-0125"

query = "프랑스의 수도를 알려줘"
messages = [{
    "role" : "user",
    "content": query
}]

response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
messages = [{
    "role": "system",
    "content": "You are a helpful assistant."
}, {
    "role": "user",
    "content": query
}]

messages = [{
    "role": "system",
    "content": "You are a humorous assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
messages = [{
    "role": "system",
    "content": "You are a sarcasm assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
messages = [{
    "role": "system",
    "content": "You are a pessimistic assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
# hello-gpt.py
import os
import openai

# API KEY 입력
openai.api_key = OPENAI_API_KEY

# model 정의
model = 'gpt-3.5-turbo'

# query 정의
query = 'Hello, World!'

# 대화 출력
response = openai.ChatCompletion.create(
    model=model,
    messages=[{"role": "user", "content": query}],
)
print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today?
